# %%
import pandas as pd
from matplotlib import pyplot as plt
marvel=pd.read_csv(r"C:\Users\DELL\Documents\Marvel DC project\characters_stats.csv")
print(marvel)
# Out:
#                Name  Alignment  Intelligence  Strength  Speed  Durability  \
# 0        Spider-Man       Hero            85        55     60          70
# 1          Iron Man       Hero           100        85     58          70
# 2              Thor       Hero            85       100     80         100
# 3              Hulk       Hero            85       100     50         100
# 4       Black Widow       Hero            85        15     30          50
# 5   Captain America       Hero            80        30     45          70
# 6            Batman       Hero           100        25     25          50
# 7          Superman       Hero            85       100    100         100
# 8      Wonder Woman       Hero            90        85     75          90
# 9             Flash       Hero            85        40    100          70
# 10          Aquaman       Hero            80        85     70          90
# 11    Green Lantern       Hero            85        65     70          80
# ...

# %%
marvel.head()
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0   Spider-Man      Hero            85        55     60          70     75
# 1     Iron Man      Hero           100        85     58          70     85
# 2         Thor      Hero            85       100     80         100    100
# 3         Hulk      Hero            85       100     50         100     80
# 4  Black Widow      Hero            85        15     30          50     40
#
#    Combat  Total
# 0      85    430
# 1      64    462
# 2      85    550
# 3      60    475
# 4      90    310

# %%
marvel.shape
# Out:
# (23, 9)

# %%
marvel["Alignment"].value_counts()
# Out:
# Alignment
# Hero         12
# Villain       8
# Anti-Hero     3
# Name: count, dtype: int64

# %%
good_characters = marvel[marvel["Alignment"] == "Hero"]
print(good_characters)
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0        Spider-Man      Hero            85        55     60          70
# 1          Iron Man      Hero           100        85     58          70
# 2              Thor      Hero            85       100     80         100
# 3              Hulk      Hero            85       100     50         100
# 4       Black Widow      Hero            85        15     30          50
# 5   Captain America      Hero            80        30     45          70
# 6            Batman      Hero           100        25     25          50
# 7          Superman      Hero            85       100    100         100
# 8      Wonder Woman      Hero            90        85     75          90
# 9             Flash      Hero            85        40    100          70
# 10          Aquaman      Hero            80        85     70          90
# 11    Green Lantern      Hero            85        65     70          80
#
# ...

# %%
good_characters.sort_values(by=["Speed"],ascending=False)
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 9             Flash      Hero            85        40    100          70
# 7          Superman      Hero            85       100    100         100
# 2              Thor      Hero            85       100     80         100
# 8      Wonder Woman      Hero            90        85     75          90
# 11    Green Lantern      Hero            85        65     70          80
# 10          Aquaman      Hero            80        85     70          90
# 0        Spider-Man      Hero            85        55     60          70
# 1          Iron Man      Hero           100        85     58          70
# 3              Hulk      Hero            85       100     50         100
# 5   Captain America      Hero            80        30     45          70
# 4       Black Widow      Hero            85        15     30          50
# 6            Batman      Hero           100        25     25          50
#
# ...

# %%
good_characters.sort_values(by=["Power"],ascending=False)
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 2              Thor      Hero            85       100     80         100
# 7          Superman      Hero            85       100    100         100
# 11    Green Lantern      Hero            85        65     70          80
# 8      Wonder Woman      Hero            90        85     75          90
# 1          Iron Man      Hero           100        85     58          70
# 3              Hulk      Hero            85       100     50         100
# 10          Aquaman      Hero            80        85     70          90
# 0        Spider-Man      Hero            85        55     60          70
# 5   Captain America      Hero            80        30     45          70
# 9             Flash      Hero            85        40    100          70
# 4       Black Widow      Hero            85        15     30          50
# 6            Batman      Hero           100        25     25          50
#
# ...

# %%
good_max_power=good_characters[good_characters["Power"]==100]
print(good_max_power)
# Out:
#              Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 2            Thor      Hero            85       100     80         100    100
# 7        Superman      Hero            85       100    100         100    100
# 11  Green Lantern      Hero            85        65     70          80    100
#
#     Combat  Total
# 2       85    550
# 7       85    570
# 11      60    460

# %%
good_characters.sort_values(by=["Total"],ascending=False)
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 7          Superman      Hero            85       100    100         100
# 2              Thor      Hero            85       100     80         100
# 8      Wonder Woman      Hero            90        85     75          90
# 3              Hulk      Hero            85       100     50         100
# 10          Aquaman      Hero            80        85     70          90
# 1          Iron Man      Hero           100        85     58          70
# 11    Green Lantern      Hero            85        65     70          80
# 0        Spider-Man      Hero            85        55     60          70
# 9             Flash      Hero            85        40    100          70
# 5   Captain America      Hero            80        30     45          70
# 6            Batman      Hero           100        25     25          50
# 4       Black Widow      Hero            85        15     30          50
#
# ...

# %%
plt.figure(figsize=(8,5))
plt.bar(list(good_max_power["Name"])[0:5],list(good_max_power["Total"])[0:5],color="green")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(good_characters["Combat"])
plt.title("Distribution of combat")
plt.xlabel("Combat")
plt.show()
